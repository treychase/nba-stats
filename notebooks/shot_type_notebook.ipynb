# %%
from scraper_functions import pull_tracking_stats
import pandas as pd
import numpy as np

df = pull_tracking_stats()

df.head()
# Out:
# Tracking stats: 100%|██████████| 11/11 [00:20<00:00,  1.90s/category, PaintTouch]
# Merging all tracking categories on PLAYER_ID...
# Combined tracking file saved: nba_tracking_combined_2025-26.csv (582 rows, 209 columns)
#    PLAYER_ID   PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  GP   W   L     MIN  \
# 0       2544  LeBron James  1610612747               LAL  60  39  21  1989.0
# 1     101108    Chris Paul  1610612746               LAC  16   4  12   228.0
# 2     200768    Kyle Lowry  1610612755               PHI  14   9   5   118.0
# 3     201142  Kevin Durant  1610612745               HOU  78  48  30  2840.0
# 4     201143    Al Horford  1610612744               GSW  45  22  23   969.0
#
#    DRIVES  DRIVE_FGM  ...  PAINT_TOUCH_PTS_PCT  PAINT_TOUCH_PASSES  \
# 0     413        109  ...                0.957                  45
# 1      31          6  ...                0.000                   2
# 2       5          0  ...                0.000                   0
# ...
