# %%
import pandas as pd
import numpy as np
from scraper_functions import pull_shot_chart

df = pull_shot_chart()

df.head()
# Out:
# Fetching players with FGA > 50...
#   -> 473 players qualify (out of full league)
# Shot charts:  26%|██▌       | 122/473 [00:19<00:29, 12.07player/s, player 1631166: 66 shots]
#     retry 1/3 for player 1630166 after 2.0s (HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=60))
#     retry 1/3 for player 1627884 after 2.0s (HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=60))
#     retry 1/3 for player 1628401 after 2.0s (HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=60))
#     retry 1/3 for player 1630217 after 2.0s (HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=60))
#     retry 1/3 for player 1628978 after 2.0s (HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=60))
#     retry 1/3 for player 203926 after 2.0s (HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=60))
# ...

# %%
from plot_functions import plot_player_season_shot_chart
import pandas as pd

df = pd.read_csv('nba_shot_chart_2025-26.csv')

df.head()
# Out:
#            GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID PLAYER_NAME  \
# 0  Shot Chart Detail  22500029            664    1642358  AJ Johnson
# 1  Shot Chart Detail  22500029            683    1642358  AJ Johnson
# 2  Shot Chart Detail  22500029            707    1642358  AJ Johnson
# 3  Shot Chart Detail  22500029            724    1642358  AJ Johnson
# 4  Shot Chart Detail  22500073            659    1642358  AJ Johnson
#
#       TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612764  Washington Wizards       4                  7
# 1  1610612764  Washington Wizards       4                  6
# 2  1610612764  Washington Wizards       4                  4
# 3  1610612764  Washington Wizards       4                  3
# 4  1610612764  Washington Wizards       4                  1
#
#    SECONDS_REMAINING  ...  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0                 53  ...  Less Than 8 ft.             5     6    53
# ...

# %%
from processing_functions import show_unique_values

show_unique_values(df)
# Out:
# {'GRID_TYPE':            GRID_TYPE   count
#  0  Shot Chart Detail  203799,
#  'PLAYER_NAME':           PLAYER_NAME  count
#  0        Jaylen Brown   1543
#  1        Tyrese Maxey   1501
#  2         Luka Dončić   1457
#  3    Donovan Mitchell   1403
#  4        Kevin Durant   1376
#  ..                ...    ...
#  445       Mac McClung     59
#  446        Chris Paul     56
#  447  Garrison Mathews     52
#  448     Yuki Kawamura     52
#  449      Nikola Topić     51
#
#  [450 rows x 2 columns],
#  'TEAM_NAME':                  TEAM_NAME  count
#  0            Atlanta Hawks   7497
#  1                Utah Jazz   7391
#  2            Chicago Bulls   7387
#  3        Memphis Grizzlies   7378
#  4       Philadelphia 76ers   7328
#  5     New Orleans Pelicans   7320
#  6    Oklahoma City Thunder   7275
#  7           Indiana Pacers   7264
#  8         Sacramento Kings   7242
#  9    Golden State Warriors   7174
#  10        Dallas Mavericks   7089
#  11          Denver Nuggets   7087
# ...

# %%
plot_player_season_shot_chart(df, 'Stephen Curry', '2025-26')
# Out:
# Could not fetch headshot for player_id=201939: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1018)>
# <Axes: title={'center': 'Stephen Curry — 2025-26 Shot Chart (799 shots)'}>
