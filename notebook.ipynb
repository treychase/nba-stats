# %%
import pandas as pd
import numpy as np
from scraper_functions import pull_shot_chart

df = pull_shot_chart()

df.head()
# Out:
# Fetching active player list...
#   -> 582 players
#   (1/582) player 1630173: 598 shots
#   (2/582) player 203500: 139 shots
#   (3/582) player 1628389: 1145 shots
#   (4/582) player 1630534: 280 shots
#   (5/582) player 1630583: 476 shots
#   (6/582) player 1641725: 37 shots
#   (7/582) player 1629638: 1195 shots
#   (8/582) player 1628960: 667 shots
#   (9/582) player 1628386: 528 shots
#   (10/582) player 1630631: 449 shots
#   (11/582) player 203937: 202 shots
#   (12/582) player 1630828: 8 shots
#   (13/582) player 203507: 598 shots
#   (14/582) player 203648: 32 shots
#   (15/582) player 1630175: 231 shots
#   (16/582) player 1628384: 804 shots
#   (17/582) player 1630166: 1064 shots
#   (18/582) player 1629028: 601 shots
#   (19/582) player 1628963: 411 shots
#   (20/582) player 1642846: 892 shots
#   (21/582) player 1642380: 68 shots
#   (22/582) player 1631116: 27 shots
#   (23/582) player 1630163: 1244 shots
#   (24/582) player 1628366: 176 shots
#   (25/582) player 1628964: 11 shots
#   (26/582) player 1631094: 1152 shots
#   (27/582) player 1630217: 1205 shots
#   (28/582) player 1630625: 12 shots
#   (29/582) player 1631230: 399 shots
#   (30/582) player 203084: 575 shots
#   (31/582) player 1630567: 1123 shots
#   (32/582) player 1642964: 71 shots
#   (33/582) player 1629628: 816 shots
#   (34/582) player 1629646: 47 shots
#   (35/582) player 1642419: 145 shots
#   (36/582) player 201587: 238 shots
#   (37/582) player 203078: 48 shots
#   (38/582) player 1630699: 76 shots
#   (39/582) player 1642866: 98 shots
#   (40/582) player 1630180: 967 shots
#   (41/582) player 1629048: 225 shots
#   (42/582) player 202687: 15 shots
#   (43/582) player 1641710: 772 shots
#   (44/582) player 1641778: 103 shots
#   (45/582) player 1631205: 6 shots
#   (46/582) player 203992: 152 shots
#   (47/582) player 1641737: 220 shots
#   (48/582) player 1626164: 1198 shots
#   (49/582) player 1628449: 25 shots
#   (50/582) player 1631123: 236 shots
#   (51/582) player 1628396: 117 shots
#   (52/582) player 1631103: 91 shots
#   (53/582) player 1631128: 389 shots
#   (54/582) player 1642886: 36 shots
#   (55/582) player 1628969: 963 shots
#   (56/582) player 1628970: 1042 shots
#   (57/582) player 1628415: 959 shots
#   (58/582) player 1641780: 24 shots
#   (59/582) player 1628971: 522 shots
#   (60/582) player 1627759: 1543 shots
#   (61/582) player 1641738: 271 shots
#   (62/582) player 1642468: 1 shots
#   (63/582) player 1628973: 1475 shots
#   (64/582) player 1642868: 265 shots
#   (65/582) player 1628418: 267 shots
#   (66/582) player 1641723: 50 shots
#   (67/582) player 1631174: 112 shots
#   (68/582) player 202710: 462 shots
#   (69/582) player 1641824: 963 shots
#   (70/582) player 1631288: 152 shots
#   (71/582) player 203484: 366 shots
#   (72/582) player 1641739: 891 shots
#   (73/582) player 203991: 227 shots
#   (74/582) player 1642928: 179 shots
#   (75/582) player 1642382: 186 shots
#   (76/582) player 1642267: 741 shots
#   (77/582) player 1642269: 292 shots
#   (78/582) player 1628975: 307 shots
#   (79/582) player 1628976: 637 shots
#   (80/582) player 1627936: 300 shots
#   (81/582) player 1642264: 817 shots
#   (82/582) player 1630658: 5 shots
#   (83/582) player 1630577: 689 shots
#   (84/582) player 1630551: 462 shots
#   (85/582) player 1631113: 137 shots
#   (86/582) player 1642353: 139 shots
#   (87/582) player 1631108: 725 shots
#   (88/582) player 1630619: 115 shots
#   (89/582) player 1631321: 334 shots
#   (90/582) player 1641740: 228 shots
#   (91/582) player 1629634: 9 shots
#   (92/582) player 203903: 526 shots
#   (93/582) player 1629651: 583 shots
#   (94/582) player 1642383: 461 shots
#   (95/582) player 1642363: 596 shots
#   (96/582) player 1642270: 684 shots
#   (97/582) player 1641730: 631 shots
#   (98/582) player 1629599: 113 shots
#   (99/582) player 1642268: 515 shots
#   (100/582) player 1628381: 659 shots
#   (101/582) player 1628380: 64 shots
#   (102/582) player 201144: 215 shots
#   (103/582) player 1626192: 85 shots
#   (104/582) player 1631451: 41 shots
#   (105/582) player 1630536: 247 shots
#   (106/582) player 1641731: 541 shots
#   (107/582) player 1642907: 648 shots
#   (108/582) player 1642384: 24 shots
#   (109/582) player 1643018: 117 shots
#   (110/582) player 1630595: 1189 shots
#   (111/582) player 203552: 49 shots
#   (112/582) player 201939: 799 shots
#   (113/582) player 1642359: 48 shots
#   (114/582) player 1630700: 777 shots
#   (115/582) player 1642368: 4 shots
#   (116/582) player 203076: 334 shots
#   (117/582) player 1631120: 64 shots
#   (118/582) player 201942: 1005 shots
#   (119/582) player 1642484: 83 shots
#   (120/582) player 1628978: 835 shots
#   (121/582) player 1631217: 363 shots
#   (122/582) player 1642885: 213 shots
#   (123/582) player 1641711: 384 shots
#   (124/582) player 1630621: 14 shots
#   (125/582) player 1631172: 398 shots
#   (126/582) player 1642265: 412 shots
#   (127/582) player 1629029: 1457 shots
#   (128/582) player 1629652: 524 shots
#   (129/582) player 1630245: 747 shots
#   (130/582) player 203083: 337 shots
#   (131/582) player 1627739: 477 shots
#   (132/582) player 1642346: 362 shots
#   (133/582) player 201142: 1376 shots
#   (134/582) player 1631105: 803 shots
#   (135/582) player 1642856: 449 shots
#   (136/582) player 1631106: 580 shots
#   (137/582) player 1641744: 98 shots
#   (138/582) player 1642845: 1030 shots
#   (139/582) player 1630162: 1231 shots
#   (140/582) player 1642348: 320 shots
#   (141/582) player 1631165: 384 shots
#   (142/582) player 203954: 697 shots
#   (143/582) player 1642400: 28 shots
#   (144/582) player 1642855: 3 shots
#   (145/582) player 1630623: 145 shots
#   (146/582) player 1629234: 156 shots
#   (147/582) player 1641787: 1 shots
#   (148/582) player 1642847: 1006 shots
#   (149/582) player 1642271: 657 shots
#   (150/582) player 1627827: 132 shots
#   (151/582) player 1642843: 1194 shots
#   (152/582) player 1642853: 215 shots
#   (153/582) player 1642280: 3 shots
#   (154/582) player 1631323: 471 shots
#   (155/582) player 1628368: 1047 shots
#   (156/582) player 1642402: 8 shots
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 import numpy as np
#       3 from scraper_functions import pull_shot_chart
# ----> 5 df = pull_shot_chart()
#       7 df.head()
#
# File ~/NBA_STATS/nba-stats/scraper_functions.py:196, in pull_shot_chart()
#     190 def _pull_player_shot_chart(player_id: int) -> pd.DataFrame:
#     191     """Pull shot chart detail for a single player for the season."""
#     192     response = shotchartdetail.ShotChartDetail(
#     193         team_id=0,
#     194         player_id=player_id,
#     195         season_nullable=SEASON,
# --> 196         season_type_all_star=SEASON_TYPE,
#     197         context_measure_simple="FGA",
#     198     )
#     199     df = response.get_data_frames()[0]
#     200     df["SEASON"] = SEASON
#
# KeyboardInterrupt:

# %%
from plot_functions import plot_player_season_shot_chart
import pandas as pd

df = pd.read_csv('nba_shot_chart_2025-26.csv')

df.head()
# Out:
#            GRID_TYPE   GAME_ID  GAME_EVENT_ID  ...  GAME_DATE  HTM  VTM
# 0  Shot Chart Detail  22500038            224  ...   20251107  SAC  OKC
# 1  Shot Chart Detail  22500038            259  ...   20251107  SAC  OKC
# 2  Shot Chart Detail  22500038            659  ...   20251107  SAC  OKC
# 3  Shot Chart Detail  22500038            672  ...   20251107  SAC  OKC
# 4  Shot Chart Detail  22500038            681  ...   20251107  SAC  OKC
#
# [5 rows x 24 columns]

# %%
plot_player_season_shot_chart(df, 'Stephen Curry', '2025-26')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SEASON'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plot_player_season_shot_chart(df, 'Stephen Curry', '2025-26')
#
# File ~/NBA_STATS/nba-stats/plot_functions.py:361, in plot_player_season_shot_chart(df, player, season, player_col, season_col, ax, gridsize, cmap, mincnt, colorbar, show_headshot, headshot_corner, zoom)
#     304 def plot_player_season_shot_chart(
#     305     df,
#     306     player,
#    (...)
#     317     zoom=0.35,
#     318 ):
#     319     """
#     320     Filter a shot chart DataFrame down to one player/season and plot the
#     321     hexbin shot chart on a court, with an optional headshot inset.
#    (...)
#     359         If no rows match the given player/season filter.
#     360     """
# --> 361     filtered = df[(df[player_col] == player) & (df[season_col] == season)]
#     363     if filtered.empty:
#     364         raise ValueError(
#     365             f"No shots found for {player_col}={player!r}, {season_col}={season!r}. "
#     366             "Check that the values match what's in the DataFrame."
#     367         )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'SEASON'
